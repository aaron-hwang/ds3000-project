# %%
# DS3000 Project
import seaborn as sns
import matplotlib as plt
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
def retrieve_year_team_data(year="", team="league"):
    """
        Arguments:
            year (int): Default: ""
            team (str): Team data is desired for. Use the 3 letter abbreviation each team in the NBA uses (in all lowercase). 
    """
    try:
        url = f"https://www.espn.com/nba/seasonleaders/_/team/{team}/year/{str(year)}"
        return pd.read_html(url)[0]
    except:
        print("Error occured while attempting to retrieve data")
retrieve_year_team_data(2019, 'league')
# Out:
#                               0                             1   \
# 0   Season Leaders - ESPN Rating  Season Leaders - ESPN Rating
# 1                             RK                        PLAYER
# 2                              1              Kemba Walker, PG
# 3                              2               Jeremy Lamb, SG
# 4                              3                Cody Zeller, C
# 5                              4             Nicolas Batum, PF
# 6                              5            Marvin Williams, F
# 7                              6                Tony Parker, G
# 8                              7             Miles Bridges, SF
# 9                              8          Willy Hernangomez, C
# 10                             9            Frank Kaminsky, PF
# 11                            10                Malik Monk, SG
# 12                            RK                        PLAYER
# 13                           NaN     Michael Kidd-Gilchrist, F
# 14                            12               Dwayne Bacon, G
# 15                            13            Bismack Biyombo, C
# 16                            14           Devonte' Graham, PG
# 17                            15                J.P. Macura, G
# 18                            16                Joe Chealey, G
# 19                            17               Shelvin Mack, G
#
#                               2                             3   \
# 0   Season Leaders - ESPN Rating  Season Leaders - ESPN Rating
# 1                           TEAM                            GP
# 2                            DAL                            82
# 3                            SAC                            79
# 4                            NOR                            49
# 5                            PHI                            75
# 6                            MIL                            75
# 7                            CHA                            56
# 8                            CHA                            80
# 9                            NOR                            58
# 10                           HOU                            47
# 11                           SAC                            73
# 12                          TEAM                            GP
# 13                           NYK                            64
# 14                            --                            43
# 15                           OKC                            54
# 16                           SAS                            46
# 17                           CLE                             2
# 18                           CHA                             1
# 19                           CHA                             4
#
#                               4                             5   \
# 0   Season Leaders - ESPN Rating  Season Leaders - ESPN Rating
# 1                            MPG                           FG%
# 2                           34.9                          .434
# 3                           28.5                          .440
# 4                           25.4                          .551
# 5                           31.4                          .450
# 6                           28.4                          .422
# 7                           17.9                          .460
# 8                           21.2                          .464
# 9                           14.0                          .519
# 10                          16.1                          .463
# 11                          17.2                          .387
# 12                           MPG                           FG%
# 13                          18.4                          .476
# 14                          17.7                          .475
# 15                          14.5                          .571
# 16                          14.7                          .343
# 17                           8.5                          .333
# 18                           8.0                          .333
# 19                          10.5                          .143
#
#                               6                             7   \
# 0   Season Leaders - ESPN Rating  Season Leaders - ESPN Rating
# 1                            FT%                           3PM
# 2                           .844                           3.2
# 3                           .888                           1.5
# 4                           .787                           0.1
# 5                           .865                           1.5
# 6                           .767                           1.9
# 7                           .734                           0.2
# 8                           .753                           0.8
# 9                           .694                           0.3
# 10                          .738                           1.1
# 11                          .882                           1.5
# 12                           FT%                           3PM
# 13                          .772                           0.3
# 14                          .739                           0.9
# 15                          .637                           0.0
# 16                          .761                           0.7
# 17                          .000                           0.0
# 18                          .000                           0.0
# 19                          .556                           0.0
#
#                               8                             9   \
# 0   Season Leaders - ESPN Rating  Season Leaders - ESPN Rating
# 1                            RPG                           APG
# 2                            4.4                           5.9
# 3                            5.5                           2.2
# 4                            6.8                           2.1
# 5                            5.2                           3.3
# 6                            5.4                           1.2
# 7                            1.5                           3.7
# 8                            4.0                           1.2
# 9                            5.4                           1.0
# 10                           3.5                           1.3
# 11                           1.9                           1.6
# 12                           RPG                           APG
# 13                           3.8                           1.0
# 14                           2.1                           1.1
# 15                           4.6                           0.6
# 16                           1.4                           2.6
# 17                           1.5                           1.0
# 18                           0.0                           1.0
# 19                           0.5                           0.3
#
#                               10                            11  \
# 0   Season Leaders - ESPN Rating  Season Leaders - ESPN Rating
# 1                           STPG                         BLKPG
# 2                            1.2                           0.4
# 3                            1.1                           0.4
# 4                            0.8                           0.8
# 5                            0.9                           0.6
# 6                            0.9                           0.8
# 7                            0.4                           0.1
# 8                            0.7                           0.6
# 9                            0.3                           0.3
# 10                           0.3                           0.3
# 11                           0.5                           0.3
# 12                          STPG                         BLKPG
# 13                           0.5                           0.6
# 14                           0.3                           0.1
# 15                           0.2                           0.8
# 16                           0.5                           0.0
# 17                           0.0                           0.0
# 18                           0.0                           0.0
# 19                           0.5                           0.0
#
#                               12                            13  \
# 0   Season Leaders - ESPN Rating  Season Leaders - ESPN Rating
# 1                           TOPG                           PTS
# 2                            2.6                          25.6
# 3                            1.0                          15.3
# 4                            1.3                          10.1
# 5                            1.6                           9.3
# 6                            0.6                          10.1
# 7                            1.3                           9.5
# 8                            0.6                           7.5
# 9                            1.0                           7.3
# 10                           0.9                           8.6
# 11                           1.2                           8.9
# 12                          TOPG                           PTS
# 13                           0.7                           6.7
# 14                           0.4                           7.3
# 15                           0.6                           4.4
# 16                           0.7                           4.7
# 17                           0.0                           3.0
# 18                           0.0                           2.0
# 19                           1.0                           2.3
#
#                               14
# 0   Season Leaders - ESPN Rating
# 1                           ESPN
# 2                           40.0
# 3                           25.9
# 4                           22.4
# 5                           20.8
# 6                           19.5
# 7                           16.0
# 8                           14.9
# 9                           14.8
# 10                          14.7
# 11                          13.2
# 12                          ESPN
# 13                          13.2
# 14                          11.8
# 15                          11.1
# 16                           9.4
# 17                           5.0
# 18                           2.8
# 19                           0.5

# %%
def clean_html(html : str):
    """
    Arguments:
        html (str): html text to parse

    Returns
        df (pd.DataFrame): A dataframe 
    """
    
    pass

# %%
def plot_data(dataframe):
    """
    Arguments:
        dataframe (pd.DataFrame()): A pandas dataframe

    Returns:
        A plot
    """
    pass
